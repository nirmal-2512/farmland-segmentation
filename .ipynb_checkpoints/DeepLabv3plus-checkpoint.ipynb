# %%
# ============================================================
# COMPLETE DEEPLABV3+ FARMLAND SEGMENTATION PIPELINE
# TRAIN ON 57 IMAGES
# PREDICT ON ALL OTHER IMAGES
# METRICS + VISUALIZATION + OVERLAY
# FULLY CORRECTED VERSION
# ============================================================

# ============================================================
# INSTALL REQUIRED LIBRARIES
# ============================================================

# pip install segmentation-models-pytorch
# pip install opencv-python
# pip install matplotlib
# pip install tqdm

# ============================================================
# IMPORTS
# ============================================================

import os
import cv2
import torch
import random
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
from tqdm import tqdm

from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

import segmentation_models_pytorch as smp

# ============================================================
# GPU CHECK
# ============================================================

print("\n===================================")
print("GPU CHECK")
print("===================================")

print("Torch Version:", torch.__version__)

print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():

    print("GPU:", torch.cuda.get_device_name(0))

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# ============================================================
# PATHS
# ============================================================

# ---------------- TRAIN SET 1 ----------------

TRAIN1_IMAGES = r"D:\farmland boundary\New folder\Train\farmlands"

# ---------------- TRAIN SET 2 ----------------

TRAIN2_IMAGES = r"D:\farmland boundary\New folder\Train 2\images"

# ---------------- GT MASKS ----------------

MASK_FOLDER = r"D:\farmland boundary\all_boundary_masks"

# ---------------- ALL IMAGES TO PREDICT ----------------

PREDICT_IMAGES = r"D:\farmland boundary\New folder\images"

# ---------------- OUTPUTS ----------------

PREDICTION_FOLDER = r"D:\farmland boundary\deeplab_predictions"

OVERLAY_FOLDER = r"D:\farmland boundary\overlay_predictions"

MODEL_PATH = r"D:\farmland boundary\deeplabv3plus_boundary.pth"

os.makedirs(PREDICTION_FOLDER, exist_ok=True)

os.makedirs(OVERLAY_FOLDER, exist_ok=True)

# ============================================================
# SETTINGS
# ============================================================

IMAGE_SIZE = 768

BATCH_SIZE = 4

EPOCHS = 100

LEARNING_RATE = 1e-4

# ============================================================
# NORMALIZE FILENAMES
# ============================================================

def normalize_name(name):

    name = os.path.splitext(name)[0]

    name = name.lower()

    name = name.replace("_pred", "")

    name = name.replace("- copy", "")

    name = name.replace(" ", "")

    name = name.strip()

    return name

# ============================================================
# DATASET
# ============================================================

class FarmlandDataset(Dataset):

    def __init__(self, image_folders, mask_folder):

        self.samples = []

        # ====================================================
        # LOAD MASKS
        # ====================================================

        mask_paths = glob(
            os.path.join(mask_folder, "*.png")
        )

        mask_dict = {}

        for mask_path in mask_paths:

            key = normalize_name(
                os.path.basename(mask_path)
            )

            mask_dict[key] = mask_path

        # ====================================================
        # MATCH TRAIN IMAGES
        # ====================================================

        for folder in image_folders:

            image_paths = sorted(

                glob(os.path.join(folder, "*.jpg")) +

                glob(os.path.join(folder, "*.png")) +

                glob(os.path.join(folder, "*.jpeg"))
            )

            for image_path in image_paths:

                key = normalize_name(
                    os.path.basename(image_path)
                )

                if key in mask_dict:

                    self.samples.append(
                        (
                            image_path,
                            mask_dict[key]
                        )
                    )

        print(f"\nVALID TRAINING PAIRS: {len(self.samples)}")

        self.transform = transforms.Compose([
            transforms.ToTensor()
        ])

    def __len__(self):

        return len(self.samples)

    def __getitem__(self, idx):

        image_path, mask_path = self.samples[idx]

        # ====================================================
        # LOAD IMAGE
        # ====================================================

        image = cv2.imread(image_path)

        image = cv2.cvtColor(
            image,
            cv2.COLOR_BGR2RGB
        )

        # ====================================================
        # LOAD MASK
        # ====================================================

        mask = cv2.imread(mask_path, 0)

        # ====================================================
        # RESIZE
        # ====================================================

        image = cv2.resize(
            image,
            (IMAGE_SIZE, IMAGE_SIZE)
        )

        mask = cv2.resize(
            mask,
            (IMAGE_SIZE, IMAGE_SIZE)
        )

        # ====================================================
        # NORMALIZE
        # ====================================================

        image = self.transform(image)

        mask = torch.tensor(
            mask / 255.0
        ).float().unsqueeze(0)

        return image, mask

# ============================================================
# LOAD DATASET
# ============================================================

dataset = FarmlandDataset(

    [TRAIN1_IMAGES, TRAIN2_IMAGES],

    MASK_FOLDER
)

if len(dataset) == 0:

    raise ValueError(
        "\nNO VALID TRAINING PAIRS FOUND"
    )

# ============================================================
# DATALOADER
# ============================================================

loader = DataLoader(

    dataset,

    batch_size=BATCH_SIZE,

    shuffle=True,

    drop_last=True
)

# ============================================================
# LOAD MODEL
# ============================================================

print("\n===================================")
print("LOADING DEEPLABV3+")
print("===================================")

model = smp.DeepLabV3Plus(

    encoder_name="resnet34",

    encoder_weights="imagenet",

    in_channels=3,

    classes=1
)

model = model.to(DEVICE)

print("\nMODEL DEVICE:")
print(next(model.parameters()).device)

# ============================================================
# LOSS FUNCTION
# ============================================================

loss_fn = smp.losses.DiceLoss(
    mode="binary"
)

# ============================================================
# OPTIMIZER
# ============================================================

optimizer = torch.optim.Adam(

    model.parameters(),

    lr=LEARNING_RATE
)

# ============================================================
# TRAINING
# ============================================================

print("\n===================================")
print("TRAINING STARTED")
print("===================================\n")

loss_history = []

for epoch in range(EPOCHS):

    model.train()

    total_loss = 0

    for images, masks in loader:

        images = images.to(DEVICE)

        masks = masks.to(DEVICE)

        # ====================================================
        # FORWARD
        # ====================================================

        preds = model(images)

        # ====================================================
        # LOSS
        # ====================================================

        loss = loss_fn(preds, masks)

        # ====================================================
        # BACKPROP
        # ====================================================

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(loader)

    loss_history.append(avg_loss)

    print(
        f"Epoch {epoch+1}/{EPOCHS} "
        f"Loss: {avg_loss:.4f}"
    )

# ============================================================
# SAVE MODEL
# ============================================================

torch.save(
    model.state_dict(),
    MODEL_PATH
)

print("\nMODEL SAVED")

# ============================================================
# TRAINING LOSS GRAPH
# ============================================================

plt.figure(figsize=(10,5))

plt.plot(loss_history)

plt.title("DeepLabV3+ Training Loss")

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.grid(True)

plt.show()

# ============================================================
# LOAD ALL PREDICTION IMAGES
# ============================================================

predict_images = sorted(

    glob(os.path.join(PREDICT_IMAGES, "*.jpg")) +

    glob(os.path.join(PREDICT_IMAGES, "*.png")) +

    glob(os.path.join(PREDICT_IMAGES, "*.jpeg"))
)

print(f"\nTOTAL IMAGES FOR PREDICTION: {len(predict_images)}")

# ============================================================
# PREDICT ON ALL IMAGES
# ============================================================

print("\n===================================")
print("PREDICTING ALL IMAGES")
print("===================================\n")

model.eval()

transform = transforms.Compose([
    transforms.ToTensor()
])

with torch.no_grad():

    for image_path in tqdm(predict_images):

        image = cv2.imread(image_path)

        if image is None:
            continue

        original = image.copy()

        h, w = image.shape[:2]

        rgb = cv2.cvtColor(
            image,
            cv2.COLOR_BGR2RGB
        )

        # ====================================================
        # RESIZE
        # ====================================================

        resized = cv2.resize(
            rgb,
            (IMAGE_SIZE, IMAGE_SIZE)
        )

        tensor = transform(resized)

        tensor = tensor.unsqueeze(0).to(DEVICE)

        # ====================================================
        # PREDICT
        # ====================================================

        pred = model(tensor)

        pred = torch.sigmoid(pred)

        pred = pred.squeeze().cpu().numpy()

        # ====================================================
        # THRESHOLD
        # ====================================================

        pred = (pred > 0.25).astype(np.uint8)

        pred = pred * 255

        # ====================================================
        # MORPHOLOGICAL CLEANING
        # ====================================================

        kernel = np.ones((3,3), np.uint8)

        pred = cv2.morphologyEx(
            pred,
            cv2.MORPH_CLOSE,
            kernel
        )

        pred = cv2.morphologyEx(
            pred,
            cv2.MORPH_OPEN,
            kernel
        )

        # ====================================================
        # RESIZE BACK
        # ====================================================

        pred = cv2.resize(
            pred,
            (w, h)
        )

        # ====================================================
        # SAVE MASK
        # ====================================================

        filename = os.path.basename(image_path)

        pred_name = (
            os.path.splitext(filename)[0] + "_pred.png"
        )

        pred_path = os.path.join(
            PREDICTION_FOLDER,
            pred_name
        )

        cv2.imwrite(pred_path, pred)

        # ====================================================
        # CREATE OVERLAY
        # ====================================================

        overlay = cv2.cvtColor(
            original,
            cv2.COLOR_BGR2RGB
        )

        overlay[pred > 0] = [255, 0, 0]

        overlay = cv2.cvtColor(
            overlay,
            cv2.COLOR_RGB2BGR
        )

        overlay_path = os.path.join(
            OVERLAY_FOLDER,
            pred_name
        )

        cv2.imwrite(
            overlay_path,
            overlay
        )

print("\n===================================")
print("ALL PREDICTIONS COMPLETE")
print("===================================")

# ============================================================
# VISUALIZATION
# ============================================================

print("\n===================================")
print("VISUALIZING RESULTS")
print("===================================")

sample_preds = random.sample(

    glob(os.path.join(PREDICTION_FOLDER, "*.png")),

    min(5, len(glob(os.path.join(PREDICTION_FOLDER, "*.png"))))
)

for pred_path in sample_preds:

    filename = os.path.basename(pred_path)

    original_name = filename.replace("_pred.png", ".png")

    original_path = os.path.join(
        PREDICT_IMAGES,
        original_name
    )

    original = cv2.imread(original_path)

    pred = cv2.imread(pred_path, 0)

    if original is None:
        continue

    original = cv2.cvtColor(
        original,
        cv2.COLOR_BGR2RGB
    )

    # ========================================================
    # OVERLAY
    # ========================================================

    overlay = original.copy()

    overlay[pred > 0] = [255, 0, 0]

    # ========================================================
    # PLOT
    # ========================================================

    plt.figure(figsize=(18,6))

    # ORIGINAL
    plt.subplot(1,3,1)

    plt.imshow(original)

    plt.title("Original Image")

    plt.axis("off")

    # PRED MASK
    plt.subplot(1,3,2)

    plt.imshow(pred, cmap="gray")

    plt.title("Predicted Boundary Mask")

    plt.axis("off")

    # OVERLAY
    plt.subplot(1,3,3)

    plt.imshow(overlay)

    plt.title("Boundary Overlay")

    plt.axis("off")

    plt.show()

# ============================================================
# METRICS EVALUATION
# ============================================================

print("\n===================================")
print("CALCULATING METRICS")
print("===================================")

# ============================================================
# METRIC FUNCTIONS
# ============================================================

def calculate_iou(y_true, y_pred):

    intersection = np.logical_and(y_true, y_pred).sum()

    union = np.logical_or(y_true, y_pred).sum()

    if union == 0:
        return 1.0

    return intersection / union


def calculate_dice(y_true, y_pred):

    intersection = np.logical_and(y_true, y_pred).sum()

    total = y_true.sum() + y_pred.sum()

    if total == 0:
        return 1.0

    return (2 * intersection) / total


def calculate_precision(y_true, y_pred):

    tp = np.logical_and(y_true == 1, y_pred == 1).sum()

    fp = np.logical_and(y_true == 0, y_pred == 1).sum()

    if (tp + fp) == 0:
        return 1.0

    return tp / (tp + fp)


def calculate_recall(y_true, y_pred):

    tp = np.logical_and(y_true == 1, y_pred == 1).sum()

    fn = np.logical_and(y_true == 1, y_pred == 0).sum()

    if (tp + fn) == 0:
        return 1.0

    return tp / (tp + fn)

# ============================================================
# LOAD GT MASKS
# ============================================================

gt_paths = glob(
    os.path.join(MASK_FOLDER, "*.png")
)

# ============================================================
# LOAD PREDICTIONS
# ============================================================

pred_paths = glob(
    os.path.join(PREDICTION_FOLDER, "*.png")
)

pred_dict = {}

for pred_path in pred_paths:

    key = normalize_name(
        os.path.basename(pred_path)
    )

    pred_dict[key] = pred_path

# ============================================================
# STORAGE
# ============================================================

ious = []
dices = []
precisions = []
recalls = []

matched = 0

# ============================================================
# LOOP THROUGH GT
# ============================================================

for gt_path in gt_paths:

    gt_name = normalize_name(
        os.path.basename(gt_path)
    )

    if gt_name not in pred_dict:

        continue

    pred_path = pred_dict[gt_name]

    matched += 1

    gt = cv2.imread(gt_path, 0)

    pred = cv2.imread(pred_path, 0)

    pred = cv2.resize(
        pred,
        (gt.shape[1], gt.shape[0])
    )

    gt = (gt > 127).astype(np.uint8)

    pred = (pred > 127).astype(np.uint8)

    ious.append(
        calculate_iou(gt, pred)
    )

    dices.append(
        calculate_dice(gt, pred)
    )

    precisions.append(
        calculate_precision(gt, pred)
    )

    recalls.append(
        calculate_recall(gt, pred)
    )

print(f"\nMATCHED SAMPLES: {matched}")

# ============================================================
# FINAL METRICS
# ============================================================

avg_iou = np.mean(ious)

avg_dice = np.mean(dices)

avg_precision = np.mean(precisions)

avg_recall = np.mean(recalls)

print("\n===================================")
print("FINAL METRICS")
print("===================================\n")

print(f"IoU Score       : {avg_iou:.4f}")

print(f"Dice Score      : {avg_dice:.4f}")

print(f"Precision Score : {avg_precision:.4f}")

print(f"Recall Score    : {avg_recall:.4f}")

# ============================================================
# METRICS BAR GRAPH
# ============================================================

metrics = [
    "IoU",
    "Dice",
    "Precision",
    "Recall"
]

values = [
    avg_iou,
    avg_dice,
    avg_precision,
    avg_recall
]

plt.figure(figsize=(8,5))

bars = plt.bar(metrics, values)

plt.ylim(0,1)

plt.ylabel("Score")

plt.title("DeepLabV3+ Segmentation Metrics")

for bar in bars:

    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 0.02,
        f"{height:.2f}",
        ha='center'
    )

plt.show()

print("\n===================================")
print("PIPELINE COMPLETE")
print("===================================")
# Out:
# ...
# GPU CHECK
# ...
# Torch Version: 2.5.1+cu121
# CUDA Available: True
# GPU: NVIDIA GeForce RTX 3050 6GB Laptop GPU
#
# VALID TRAINING PAIRS: 57
#
# ...
# LOADING DEEPLABV3+
# ...
#
# MODEL DEVICE:
# cuda:0
#
# ...
# TRAINING STARTED
# ...
#
# Epoch 1/100 Loss: 0.8786
# Epoch 2/100 Loss: 0.8609
# Epoch 3/100 Loss: 0.8455
# Epoch 4/100 Loss: 0.8251
# Epoch 5/100 Loss: 0.8039
# Epoch 6/100 Loss: 0.7878
# Epoch 7/100 Loss: 0.7730
# Epoch 8/100 Loss: 0.7525
# Epoch 9/100 Loss: 0.7360
# Epoch 10/100 Loss: 0.7206
# Epoch 11/100 Loss: 0.7084
# Epoch 12/100 Loss: 0.6922
# Epoch 13/100 Loss: 0.6776
# Epoch 14/100 Loss: 0.6688
# Epoch 15/100 Loss: 0.6593
# Epoch 16/100 Loss: 0.6545
# Epoch 17/100 Loss: 0.6545
# Epoch 18/100 Loss: 0.6402
# Epoch 19/100 Loss: 0.6332
# Epoch 20/100 Loss: 0.6218
# Epoch 21/100 Loss: 0.6197
# Epoch 22/100 Loss: 0.6145
# Epoch 23/100 Loss: 0.6054
# Epoch 24/100 Loss: 0.5991
# Epoch 25/100 Loss: 0.5947
# Epoch 26/100 Loss: 0.5915
# Epoch 27/100 Loss: 0.5873
# Epoch 28/100 Loss: 0.5793
# ...

# %%
# !pip install onnx onnxruntime-gpu
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
#     --------------------------------------- 0.3/16.4 MB ? eta -:--:--
# ...

# %%
# %run export.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\magics\execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\utils\path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'export.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('run', 'export.py')
#
# ...

# %%
import torch
import segmentation_models_pytorch as smp

MODEL_PATH = r"D:\farmland boundary\best_deeplab_model.pth"

model = smp.DeepLabV3Plus(
    encoder_name="resnet101",
    encoder_weights=None,
    in_channels=3,
    classes=1
)

model.load_state_dict(
    torch.load(MODEL_PATH, map_location="cpu")
)

model.eval()

dummy_input = torch.randn(1, 3, 1024, 1024)

torch.onnx.export(
    model,
    dummy_input,
    r"D:\farmland boundary\deeplabv3plus.onnx",
    export_params=True,
    opset_version=17,
    do_constant_folding=True,
    input_names=["input"],
    output_names=["output"],
    dynamic_axes={
        "input": {0: "batch"},
        "output": {0: "batch"}
    }
)

print("ONNX Export Complete")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5240\2470459724.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(MODEL_PATH, map_location="cpu")
# ...

# %%
import os

for root, dirs, files in os.walk(r"D:\farmland boundary"):
    for file in files:
        if file.endswith(".pth"):
            print(os.path.join(root, file))
# Out:
# D:\farmland boundary\boundary_model.pth
# D:\farmland boundary\deeplabv3plus_boundary.pth
# D:\farmland boundary\deeplabv3plus_resnet101_best.pth
# D:\farmland boundary\farmland_model.pth
# D:\farmland boundary\farmland_unet.pth
# D:\farmland boundary\all_train_images\all_boundary_masks\sam_vit_b_01ec64 (1).pth
# D:\farmland boundary\SAM\sam_vit_b_01ec64 (1).pth
